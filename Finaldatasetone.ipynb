# %%
#importing all required python libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt #use to visualize dataset vallues
import seaborn as sns

# %%
#code to load infraestructura_Point_Features_Stats dataset values
dataset = pd.read_excel("C:\\Users\\manis\\Dropbox\\My PC (DESKTOP-ERGESDR)\\Desktop\\DAEN 690\\DataVisualization\\Dataset\\infraestructura_Point_Features_Stats.xlsx")
dataset
# Out:
#      objectid  level  layer_name          x          y
# 0           1  10 ft  Aeropuerto -65.303564  18.311617
# 1           2  10 ft  Aeropuerto -66.097863  18.455820
# 2           3  10 ft  Aeropuerto -66.003639  18.438499
# 3           4  10 ft  Aeropuerto -66.021461  17.982921
# 4           5  10 ft    Escuelas -66.719712  17.997166
# ..        ...    ...         ...        ...        ...
# 521       555  10 ft  Hospitales -67.149668  18.205891
# 522       556  10 ft  Hospitales -66.065605  18.452582
# 523       557  10 ft  Hospitales -66.722429  18.469876
# 524       558  10 ft  Hospitales -67.147513  18.198079
# 525       559  10 ft  Hospitales -66.074832  18.448652
#
# [526 rows x 5 columns]

# %%
#finding sum of missing values
dataset.isnull().sum()
# Out:
# objectid      0
# level         0
# layer_name    0
# x             0
# y             0
# dtype: int64

# %%
#describing dataset to know distribution of values ranges in each column
dataset.describe()
# Out:
#          objectid           x           y
# count  526.000000  526.000000  526.000000
# mean   287.026616  -66.376071   18.288453
# std    163.959610    0.486596    0.186701
# min      1.000000  -67.242969   17.947493
# 25%    132.250000  -66.719712   18.175278
# 50%    296.500000  -66.138375   18.420058
# 75%    427.750000  -66.047358   18.438502
# max    559.000000  -65.299745   18.486731

# %%
#visualizing graph of different layers with different sea feets level
#in graph x-axis represents layer names and y-axis represents counts of feets
#each different line represents feet type as 10, 7, 3 or 1
data = dataset.groupby(["layer_name", "level"]).size().sort_values(ascending=False).reset_index(name='count')
g = sns.catplot(x="layer_name", y="count", hue='level', data=data, kind='point', height=3, aspect=1.9)
g.set_xticklabels(rotation=90)
g.set_axis_labels("Infrastructure Type", "Count of Structures Affected")
plt.title("Impact of Expected Sea Level Rise on Infrastructure by Type and Level")
plt.show()

# %%
data = dataset.groupby(["layer_name", "level"]).size().sort_values(ascending=False).reset_index(name='count')

# Display the data table
print(data)
# Out:
#                    layer_name  level  count
# 0                    Escuelas  10 ft     89
# 1                    Antennas  10 ft     57
# 2                    Escuelas   7 ft     52
# 3                    Iglesias  10 ft     49
# 4               Subestaciones  10 ft     46
# 5                    Antennas   7 ft     35
# 6   Infraestructura Histórica  10 ft     33
# 7                    Iglesias   7 ft     31
# 8                  Hospitales  10 ft     21
# 9   Infraestructura Histórica   7 ft     17
# 10              Subestaciones   7 ft     15
# 11                   Iglesias   3 ft     13
# 12        Plantas Generadoras  10 ft     12
# 13                   Antennas   3 ft     12
# 14                 Hospitales   7 ft      9
# 15                   Escuelas   3 ft      5
# 16              Subestaciones   3 ft      5
# 17  Infraestructura Histórica   3 ft      5
# 18                 Aeropuerto  10 ft      4
# 19                   Antennas   1 ft      3
# ...

# %%
data = dataset.groupby(["layer_name"]).size().sort_values(ascending=False).reset_index(name='count')
g = sns.barplot(x = 'layer_name', y = 'count', data = data)
g.set_xticklabels(g.get_xticklabels(), rotation=70)
g.get_figure().set_size_inches(6, 3)
plt.title("Visualizing which layers maximum and minimum occurring in dataset")
plt.show()
# Out:
# C:\Users\manis\AppData\Local\Temp\ipykernel_25420\3945773486.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   g.set_xticklabels(g.get_xticklabels(), rotation=70)

# %%
from matplotlib.ticker import FixedLocator

# %%
data = dataset.groupby(["layer_name"]).size().sort_values(ascending=False).reset_index(name='count')
g = sns.barplot(x = 'layer_name', y = 'count', data = data)
g.set_xticklabels(g.get_xticklabels(), rotation=70)
g.get_figure().set_size_inches(6, 3)
plt.title("Visualizing which layers maximum and minimum occurring in dataset")
plt.show()
# Out:
# C:\Users\manis\AppData\Local\Temp\ipykernel_25420\3945773486.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   g.set_xticklabels(g.get_xticklabels(), rotation=70)

# %%
from matplotlib.ticker import FixedLocator

g.xaxis.set_major_locator(FixedLocator(g.get_xticks()))  # Ensure fixed tick positions
g.set_xticklabels(g.get_xticklabels(), rotation=70)  # Now set labels with rotation
# Out:
# [Text(0, 0, 'Escuelas'),
#  Text(1, 0, 'Antennas'),
#  Text(2, 0, 'Iglesias'),
#  Text(3, 0, 'Subestaciones'),
#  Text(4, 0, 'Infraestructura Histórica'),
#  Text(5, 0, 'Hospitales'),
#  Text(6, 0, 'Plantas Generadoras'),
#  Text(7, 0, 'Aeropuerto')]

# %%
data = dataset.groupby(["layer_name"]).size().sort_values(ascending=False).reset_index(name='count')
g = sns.barplot(x = 'layer_name', y = 'count', data = data)
g.set_xticklabels(g.get_xticklabels(), rotation=70)
g.get_figure().set_size_inches(6, 3)
plt.title("Visualizing which layers maximum and minimum occurring in dataset")
plt.show()
# Out:
# C:\Users\manis\AppData\Local\Temp\ipykernel_25420\3945773486.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   g.set_xticklabels(g.get_xticklabels(), rotation=70)

# %%
# Assuming 'data' is your dataframe with 'layer_name' and 'count'
data = dataset.groupby(["layer_name"]).size().sort_values(ascending=False).reset_index(name='count')

# Create a barplot with different colors for each bar
g = sns.barplot(x='layer_name', y='count', data=data, palette='husl')  # or try other palettes like 'Set2', 'coolwarm', etc.

# Rotate x-tick labels
g.set_xticklabels(g.get_xticklabels(), rotation=70)

# Set figure size
g.get_figure().set_size_inches(6, 3)

# Set title
plt.title("Visualizing which layers occur most and least frequently in dataset")

# Show plot
plt.show()
# Out:
# C:\Users\manis\AppData\Local\Temp\ipykernel_25420\1785458900.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   g = sns.barplot(x='layer_name', y='count', data=data, palette='husl')  # or try other palettes like 'Set2', 'coolwarm', etc.
# C:\Users\manis\AppData\Local\Temp\ipykernel_25420\1785458900.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   g.set_xticklabels(g.get_xticklabels(), rotation=70)

# %%
df = pd.read_csv("C:\\Users\\manis\\Dropbox\\My PC (DESKTOP-ERGESDR)\\Desktop\\DAEN 690\\DataVisualization\\Dataset\\infraestructura_Point_Features_Stats.xlsx")

# Check for missing values and handle them (optional)
df.dropna(subset=['layer', 'infrastructure_type'], inplace=True)

# Set up the plot style for professionalism
sns.set(style="whitegrid")

# Create a box plot to visualize the variation in sea level rise ('layer') across infrastructure types
plt.figure(figsize=(10, 6))
sns.boxplot(x='infrastructure_type', y='layer', data=df, palette='coolwarm')

# Add titles and labels for clarity
plt.title('Expected Sea Level Rise by Infrastructure Type', fontsize=16)
plt.xlabel('Infrastructure Type', fontsize=14)
plt.ylabel('Expected Sea Level Rise (Layer)', fontsize=14)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df = pd.read_csv("C:\\Users\\manis\\Dropbox\\My PC (DESKTOP-ERGESDR)\\Desktop\\DAEN 690\\DataVisualization\\Dataset\\infraestructura_Point_Features_Stats.xlsx")
#       3 # Check for missing values and handle them (optional)
#       4 df.dropna(subset=['layer', 'infrastructure_type'], inplace=True)
#
# ...
